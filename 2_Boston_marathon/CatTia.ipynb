# %% [markdown]
# # Add Columns

# %% [markdown]
# ### New Feature -- AgeGroup

# %%
# Define age_division
def age_to_age_division(age):
    if age<=34             : return 0
    if (35<=age)&(age<=39) : return 1
    if (40<=age)&(age<=44) : return 2
    if (45<=age)&(age<=49) : return 3
    if (50<=age)&(age<=54) : return 4
    if (55<=age)&(age<=59) : return 5
    if (60<=age)&(age<=64) : return 6
    if (65<=age)&(age<=69) : return 7
    if (70<=age)&(age<=74) : return 8
    if (75<=age)&(age<=79) : return 9
    if age>=80             : return 10
    
age_division = df['age'].apply(age_to_age_division)

df.insert(14, 'age_division', value=age_division)

# %%
# Define age_division
def age_to_age_division(age):
    if age<=34             : return 0
    if (35<=age)&(age<=44) : return 1
    if age>=45             : return 2
    
    
age_division = df['age'].apply(age_to_age_division)

df.insert(14, 'age_division', value=age_division)

# %%
df[['age', 'age_division']].head(8)
# Out:
#    age  age_division
# 0   47             3
# 1   33             0
# 2   41             2
# 3   24             0
# 4   40             2
# 5   29             0
# 6   28             0
# 7   29             0

# %% [markdown]
# ### New Features -- avgSpeed*

# %%
milestones = [['5k', '10k', '20k', '25k', '30k', '35k', '40k'],
              [ 5,    10,    20,    25,    30,    35,    40]]
loc = 10
for i, j in zip(*milestones):
    values = df[i] / j
    df.insert(loc, i+'_avgSpeed', values)
    loc += 1

# %%
df.head(8)
# Out:
#       5k    10k    20k   half    25k    30k     35k     40k  official  pace  \
# 0   8.02  17.37  37.65  39.72  47.67  59.18   71.40   80.43     85.25  3.27
# 1  16.22  32.58  65.83  69.47  82.43  99.33  116.37  132.10    138.95  5.30
# 2   7.75  16.62  36.10  38.03  45.80  56.45   67.42   76.10     80.60  3.08
# 3  16.20  32.57  65.83  69.47  82.43  99.33  116.37  132.95    140.58  5.37
# 4   8.02  17.12  36.58  38.60  46.37  57.03   67.83   76.72     81.23  3.10
# 5  16.22  32.58  65.83  69.47  82.45  99.33  116.37  132.95    140.68  5.37
# 6   8.38  17.65  37.65  39.72  47.67  58.60   70.23   79.83     84.65  3.23
# 7  15.17  30.48  61.62  64.85  76.95  92.52  107.47  122.80    129.83  4.97
#
#    5k_avgSpeed  10k_avgSpeed  20k_avgSpeed  25k_avgSpeed  30k_avgSpeed  \
# 0        1.604         1.737        1.8825        1.9068      1.972667
# 1        3.244         3.258        3.2915        3.2972      3.311000
# 2        1.550         1.662        1.8050        1.8320      1.881667
# 3        3.240         3.257        3.2915        3.2972      3.311000
# 4        1.604         1.712        1.8290        1.8548      1.901000
# 5        3.244         3.258        3.2915        3.2980      3.311000
# 6        1.676         1.765        1.8825        1.9068      1.953333
# 7        3.034         3.048        3.0810        3.0780      3.084000
#
#    35k_avgSpeed  40k_avgSpeed  rank_overall  rank_in_gender_only  \
# 0      2.040000       2.01075             8                    8
# 1      3.324857       3.30250            21                    1
# 2      1.926286       1.90250             1                    1
# 3      3.324857       3.32375            27                    3
# 4      1.938000       1.91800             2                    2
# 5      3.324857       3.32375            28                    4
# 6      2.006571       1.99575             4                    4
# 7      3.070571       3.07000             5                    5
#
#    rank_in_division  age  age_division gender country   state
# 0                 8   47             3      M     JPN  others
# 1                 1   33             0      F     KEN  others
# 2                 1   41             2      M     RSA  others
# 3                 3   24             0      F     ETH  others
# 4                 2   40             2      M     JPN  others
# 5                 4   29             0      F     KEN  others
# 6                 4   28             0      M     SUI  others
# 7                 5   29             0      M     ETH  others

# %%
profile = ProfileReport(df, title='Profiling Report -- Boston Marathon 2014', explorative=True)
profile.to_file("Boston_2014_Profiling.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=39.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…

# %%
list(df.select_dtypes(include=numerics).columns.values)
# Out:
# ['5k',
#  '10k',
#  '20k',
#  'half',
#  '25k',
#  '30k',
#  '35k',
#  '40k',
#  'official',
#  'pace',
#  'age']

# %%
from yellowbrick.cluster import InterclusterDistance

# Instantiate the clustering model and visualizer
model = KMeans(n_clusters=optimum_k, random_state=10)
visualizer = InterclusterDistance(model)

visualizer.fit(df)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Analysis of Mean Average Silhouette Coefficient

# %%
# Average Silhouette score
from yellowbrick.cluster import silhouette_visualizer

the_range = [5, 6, 8]

for k in the_range:
    silhouette_visualizer(KMeans(k, random_state=10), df, colors='yellowbrick')

# %% [markdown]
# Searching for the optimum k of clusters, we plot the average score and expect:
# * Firstly, The mean value should be as ***close to 1*** as possible
# * Secondly, The plot of each cluster should be ***above the mean value*** as much as possible. Any plot region below the mean value is not desirable.
# * Lastly, the ***width of the plot should be as uniform*** as possible.
#
# ***Comments***
# * All of plot respecting to k have below-average clusters.
# * At k of 15 and 20, some clusters are too thin, is thers a signal of overfit (over-clustering)?
#
# I don't know how to interprete better, so I take a shot at BIC score with a Gaussian Mixture Model. Let's choose ***k = 6***.

# %%
# Save to csv
cluster = pd.DataFrame(data=cluster_labels, columns=['cluster'])
cluster.to_csv('clusterLabel_OPTICS.csv', index=False)

# %% [markdown]
# # Test

# %%
cluster_1.groupby('age_division').count()
# Out:
#               Unnamed: 0    5k   10k   20k  half   25k   30k   35k   40k  \
# age_division
# 0.0                 3795  3795  3795  3795  3795  3795  3795  3795  3795
# 0.1                 2109  2109  2109  2109  2109  2109  2109  2109  2109
# 0.2                 2618  2618  2618  2618  2618  2618  2618  2618  2618
# 0.3                 2905  2905  2905  2905  2905  2905  2905  2905  2905
# 0.4                 2458  2458  2458  2458  2458  2458  2458  2458  2458
# 0.5                 1768  1768  1768  1768  1768  1768  1768  1768  1768
# 0.6                 1097  1097  1097  1097  1097  1097  1097  1097  1097
# 0.7                  529   529   529   529   529   529   529   529   529
# 0.8                  157   157   157   157   157   157   157   157   157
# 0.9                   41    41    41    41    41    41    41    41    41
# 1.0                    7     7     7     7     7     7     7     7     7
#
#               official  pace  5k_avgSpeed  10k_avgSpeed  20k_avgSpeed  \
# age_division
# 0.0               3795  3795         3795          3795          3795
# 0.1               2109  2109         2109          2109          2109
# 0.2               2618  2618         2618          2618          2618
# 0.3               2905  2905         2905          2905          2905
# 0.4               2458  2458         2458          2458          2458
# 0.5               1768  1768         1768          1768          1768
# 0.6               1097  1097         1097          1097          1097
# 0.7                529   529          529           529           529
# 0.8                157   157          157           157           157
# 0.9                 41    41           41            41            41
# 1.0                  7     7            7             7             7
#
#               25k_avgSpeed  30k_avgSpeed  35k_avgSpeed  40k_avgSpeed  \
# age_division
# 0.0                   3795          3795          3795          3795
# 0.1                   2109          2109          2109          2109
# 0.2                   2618          2618          2618          2618
# 0.3                   2905          2905          2905          2905
# 0.4                   2458          2458          2458          2458
# 0.5                   1768          1768          1768          1768
# 0.6                   1097          1097          1097          1097
# 0.7                    529           529           529           529
# 0.8                    157           157           157           157
# 0.9                     41            41            41            41
# 1.0                      7             7             7             7
#
#               rank_overall  rank_in_gender_only  rank_in_division   age  \
# age_division
# 0.0                   3795                 3795              3795  3795
# 0.1                   2109                 2109              2109  2109
# 0.2                   2618                 2618              2618  2618
# 0.3                   2905                 2905              2905  2905
# 0.4                   2458                 2458              2458  2458
# 0.5                   1768                 1768              1768  1768
# 0.6                   1097                 1097              1097  1097
# 0.7                    529                  529               529   529
# 0.8                    157                  157               157   157
# 0.9                     41                   41                41    41
# 1.0                      7                    7                 7     7
#
#               gender  country  state  city  cluster
# age_division
# 0.0             3795     3795   3795  3795     3795
# 0.1             2109     2109   2109  2109     2109
# 0.2             2618     2618   2618  2618     2618
# 0.3             2905     2905   2905  2905     2905
# 0.4             2458     2458   2458  2458     2458
# 0.5             1768     1768   1768  1768     1768
# 0.6             1097     1097   1097  1097     1097
# 0.7              529      529    529   529      529
# 0.8              157      157    157   157      157
# 0.9               41       41     41    41       41
# 1.0                7        7      7     7        7

# %%
age_cluster_0 = cluster_0.groupby('age_division').count().cluster
px.bar(age_cluster_0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-89fd55c9a920> in <module>
# ----> 1 age_cluster_0 = cluster_0.groupby('age_division').count().cluster
#       2 px.bar(age_cluster_0)
#       3
#
# ~/anaconda3/envs/boston/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~/anaconda3/envs/boston/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     408                 sort=sort,
#     409                 observed=observed,
# --> 410                 mutated=self.mutated,
#     411             )
#     412
#
# ~/anaconda3/envs/boston/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     598                 in_axis, name, level, gpr = False, None, gpr, None
#     599             else:
# --> 600                 raise KeyError(gpr)
#     601         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     602             # Add key to exclusions
#
# KeyError: 'age_division'

# %%
age_cluster_1 = cluster_1.groupby('age_division').count().cluster
px.bar(age_cluster_1)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
cluster_1.groupby('age_division').count().cluster
# Out:
# age_division
# 0.0    3795
# 0.1    2109
# 0.2    2618
# 0.3    2905
# 0.4    2458
# 0.5    1768
# 0.6    1097
# 0.7     529
# 0.8     157
# 0.9      41
# 1.0       7
# Name: cluster, dtype: int64

# %%
cluster_gender.plot(kind='bar', 
                    title='Gender of Clusters',
                    grid=False)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# # Test -- lay countries

# %% [markdown]
# ## Data for Charateristic

# %%
# Not using in this notebook, but in my excel file to presentation
for i in range(n_cluster):
    index = str(i)
    temp = df[df.cluster==i]
    temp.to_csv('cluster_' + index + '.csv', index=False)

# %%
test = pd.read_csv('cluster_0.csv')

test
# Out:
#                       name     5k    10k     20k    half     25k     30k  \
# 0         Malik, Ronald W.  13.32  29.60   67.87   71.37   87.28  111.58
# 1      Ahearn, Christopher  16.20  34.50   78.82   83.05  101.08  130.02
# 2             Ebiner, Matt  18.43  36.82   74.15   78.22   92.77  112.35
# 3               Meigs, Tim  24.88  49.67   94.85   99.67  117.33  140.03
# 4       Fernandez, Douglas  17.77  35.97   72.93   77.05   91.40  109.83
# ...                    ...    ...    ...     ...     ...     ...     ...
# 7129  Tamuleviz, Joseph G.  32.23  68.95  150.40  159.45  198.90  248.05
# 7130     Maggiacomo, Derek  28.38  57.75  117.42  124.03  149.88  186.15
# 7131        Reno, James T.  34.12  69.53  144.65  153.02  190.55  237.68
# 7132         Morris, David  37.10  76.75  163.78  173.45  210.07  257.60
# 7133  Kirchner, Jeffrey T.  26.92  53.63  108.03  114.13  135.02  161.83
#
#          35k     40k  official   pace  rank_overall  rank_in_gender_only  \
# 0     137.20  153.87    163.20   6.23            49                   39
# 1     161.52  180.40    191.33   7.30            53                   42
# 2     132.80  152.72    161.42   6.17           389                  362
# 3     163.32  187.27    198.20   7.57          5969                 5182
# 4     128.50  146.63    154.72   5.92           172                  151
# ...      ...     ...       ...    ...           ...                  ...
# 7129  300.27  351.20    371.38  14.17         31227                17260
# 7130  223.22  261.43    278.13  10.62         24550                14068
# 7131  288.30  336.62    356.20  13.60         30827                17092
# 7132  305.57  352.18    374.22  14.28         31296                17288
# 7133  189.68  216.48    228.30   8.72         14844                 9771
#
#       rank_in_division  age gender country state        city    bib  cluster
# 0                   37   59      M     USA    IL     Tremont    W49        0
# 1                   39   52      M     USA    MA  Framingham    W51        0
# 2                    5   53      M     USA    CA      Covina    219        0
# 3                  753   47      M     USA    NC     Raleigh    310        0
# 4                    2   53      M     USA    VA    Richmond    408        0
# ...                ...  ...    ...     ...   ...         ...    ...      ...
# 7129              2434   54      M     USA    MA      Millis  35895        0
# 7130              2187   44      M     USA    MA     Duxbury  35899        0
# 7131              1725   56      M     USA    MA     Reading  35902        0
# 7132              2598   44      M     USA    MA     Wayland  35907        0
# 7133              1396   54      M     USA    PA   Lancaster  35912        0
#
# [7134 rows x 21 columns]

# %%
test.country.value_counts()
# Out:
# USA    7134
# Name: country, dtype: int64

# %%
for i in range(n_cluster):
    index = str(i)
    tmp = pd.read_csv('cluster_'+index+'.csv')
    print('---- Cluster '+index+'----')
    print(tmp.country.count())
# Out:
# ---- Cluster 0----
# 1565
# ---- Cluster 1----
# 14333
# ---- Cluster 2----
# 12596
# ---- Cluster 3----
# 1905
# ---- Cluster 4----
# 1235

# %%
for i in range(5) : print('CLUSTER '+str(i), df[df.cluster==i].describe())
# Out:
# CLUSTER 0                 5k          10k          20k         half          25k  \
# count  1565.000000  1565.000000  1565.000000  1565.000000  1565.000000
# mean     26.111233    52.576556   107.329105   113.311502   135.929042
# std       3.155625     6.552830    14.444884    15.299051    19.187363
# min       9.250000    19.750000    43.150000    45.420000    54.880000
# 25%      24.070000    48.280000    98.000000   103.450000   123.750000
# 50%      25.880000    51.930000   105.350000   111.170000   132.900000
# 75%      27.770000    55.920000   114.350000   120.770000   145.330000
# max      39.200000    74.930000   177.970000   188.170000   227.920000
#
#                30k          35k          40k     official         pace  \
# count  1565.000000  1565.000000  1565.000000  1565.000000  1565.000000
# mean    166.477367   198.393853   229.807553   243.474850     9.294524
# std      24.791545    30.836702    36.804387    39.201249     1.494827
# min      68.180000    81.580000    92.070000    97.400000     3.720000
# 25%     150.480000   178.580000   205.850000   218.100000     8.330000
# 50%     162.150000   192.670000   222.670000   235.730000     9.000000
# 75%     178.700000   213.920000   248.630000   263.200000    10.050000
# max     282.450000   332.250000   391.000000   416.550000    15.730000
#
#        rank_overall  rank_in_gender_only  rank_in_division          age  \
# count   1565.000000          1565.000000       1565.000000  1565.000000
# mean   17014.589137          6415.099042       1283.722045    44.495847
# std     7187.175554          3745.234858       1306.216398     9.793299
# min       21.000000             1.000000          1.000000    20.000000
# 25%    11827.000000          3359.000000        357.000000    38.000000
# 50%    16923.000000          6276.000000        886.000000    45.000000
# 75%    22356.000000          9312.000000       1733.000000    51.000000
# max    31826.000000         14310.000000       6733.000000    78.000000
#
#         age_ranges  cluster
# count  1565.000000   1565.0
# mean      1.369968      0.0
# std       0.751294      0.0
# min       0.000000      0.0
# 25%       1.000000      0.0
# 50%       2.000000      0.0
# 75%       2.000000      0.0
# max       2.000000      0.0
# CLUSTER 1                  5k           10k           20k          half           25k  \
# count  14333.000000  14333.000000  14333.000000  14333.000000  14333.000000
# mean      24.803758     49.776520    101.250906    106.924215    128.347773
# std        4.340697      8.926155     19.443033     20.632370     25.969316
# min        8.380000     17.670000     38.330000     40.450000     48.550000
# 25%       21.470000     42.850000     86.170000     90.930000    108.370000
# 50%       23.880000     47.900000     96.800000    102.220000    122.020000
# 75%       27.880000     55.800000    113.270000    119.650000    143.850000
# max       43.230000     88.030000    189.020000    198.400000    241.570000
#
#                 30k           35k           40k      official          pace  \
# count  14333.000000  14333.000000  14333.000000  14333.000000  14333.000000
# mean     157.579099    188.889439    220.636976    234.252574      8.942741
# std       33.617119     42.068454     50.017973     53.062205      2.023733
# min       59.770000     70.830000     80.180000     84.820000      3.250000
# 25%      131.800000    156.680000    181.970000    193.170000      7.380000
# 50%      148.920000    177.930000    208.300000    221.550000      8.470000
# 75%      177.450000    214.420000    251.870000    267.730000     10.220000
# max      297.300000    356.230000    409.550000    439.670000     16.780000
#
#        rank_overall  rank_in_gender_only  rank_in_division           age  \
# count  14333.000000         14333.000000      14333.000000  14333.000000
# mean   14088.786576          8858.583828       1824.324077     43.821391
# std     9848.786628          5140.073795       1500.671610     11.628113
# min        1.000000             1.000000          1.000000     18.000000
# 25%     4844.000000          4350.000000        651.000000     35.000000
# 50%    12888.000000          8951.000000       1459.000000     44.000000
# 75%    23109.000000         13394.000000       2473.000000     52.000000
# max    31909.000000         17562.000000       5909.000000     81.000000
#
#          age_ranges  cluster
# count  14333.000000  14333.0
# mean       1.244261      1.0
# std        0.818765      0.0
# min        0.000000      1.0
# 25%        1.000000      1.0
# 50%        1.000000      1.0
# 75%        2.000000      1.0
# max        2.000000      1.0
# CLUSTER 2                  5k           10k           20k          half           25k  \
# count  12596.000000  12596.000000  12596.000000  12596.000000  12596.000000
# mean      27.063321     54.525937    111.637320    117.870169    141.752008
# std        3.773218      7.929621     17.866151     18.924584     23.989799
# min       10.120000     20.650000     43.120000     45.430000     54.180000
# 25%       24.250000     48.730000     98.600000    104.030000    124.220000
# 50%       26.300000     52.770000    107.300000    113.275000    135.875000
# 75%       29.550000     59.430000    121.880000    128.685000    155.230000
# max       45.680000     91.080000    187.620000    198.450000    240.020000
#
#                 30k           35k           40k      official          pace  \
# count  12596.000000  12596.000000  12596.000000  12596.000000  12596.000000
# mean     173.830281    207.513002    240.715483    254.786749      9.726046
# std       30.834427     38.138699     44.761432     47.234654      1.801655
# min       66.480000     79.150000     89.870000     95.100000      3.630000
# 25%      151.100000    179.350000    207.180000    219.280000      8.370000
# 50%      165.870000    197.420000    228.970000    242.610000      9.270000
# 75%      191.035000    229.222500    266.885000    282.600000     10.780000
# max      300.730000    365.620000    433.280000    461.870000     17.620000
#
#        rank_overall  rank_in_gender_only  rank_in_division           age  \
# count  12596.000000         12596.000000      12596.000000  12596.000000
# mean   18509.312798          7197.070340       2265.706097     39.173627
# std     7853.443305          4150.388962       1984.417050     10.433925
# min       17.000000             1.000000          1.000000     18.000000
# 25%    12202.750000          3575.750000        661.000000     30.000000
# 50%    18616.000000          7224.000000       1586.000000     39.000000
# 75%    25177.750000         10831.250000       3643.500000     47.000000
# max    31926.000000         14355.000000       6979.000000     81.000000
#
#          age_ranges  cluster
# count  12596.000000  12596.0
# mean       0.964195      2.0
# std        0.829912      0.0
# min        0.000000      2.0
# 25%        0.000000      2.0
# 50%        1.000000      2.0
# 75%        2.000000      2.0
# max        2.000000      2.0
# CLUSTER 3                 5k          10k          20k         half          25k  \
# count  1905.000000  1905.000000  1905.000000  1905.000000  1905.000000
# mean     23.924173    48.121071    97.969307   103.464163   124.107675
# std       4.074630     8.300786    17.730726    18.818960    23.538346
# min       7.750000    16.620000    36.100000    38.030000    45.800000
# 25%      21.080000    42.150000    85.150000    89.800000   107.120000
# 50%      23.320000    46.900000    95.150000   100.450000   119.750000
# 75%      26.570000    53.450000   108.830000   114.700000   137.570000
# max      44.220000    76.930000   164.550000   174.750000   216.170000
#
#                30k          35k          40k     official         pace  \
# count  1905.000000  1905.000000  1905.000000  1905.000000  1905.000000
# mean    152.462682   182.747323   213.293008   226.786950     8.658052
# std      30.525582    38.211782    45.664803    48.669791     1.856304
# min      56.450000    67.420000    76.100000    80.600000     3.080000
# 25%     130.270000   155.050000   180.170000   191.530000     7.320000
# 50%     146.170000   174.600000   204.150000   216.900000     8.280000
# 75%     168.880000   202.920000   238.500000   253.800000     9.680000
# max     278.450000   341.380000   405.330000   432.700000    16.520000
#
#        rank_overall  rank_in_gender_only  rank_in_division          age  \
# count   1905.000000          1905.000000       1905.000000  1905.000000
# mean   12983.574803          8323.461417       1418.083465    46.871916
# std     9242.233389          4871.938866       1175.249953     9.943928
# min        1.000000             1.000000          1.000000    19.000000
# 25%     4445.000000          4031.000000        486.000000    40.000000
# 50%    11429.000000          8281.000000       1204.000000    47.000000
# 75%    20749.000000         12306.000000       2037.000000    53.000000
# max    31893.000000         17552.000000       5873.000000    80.000000
#
#         age_ranges  cluster
# count  1905.000000   1905.0
# mean      1.487139      3.0
# std       0.680589      0.0
# min       0.000000      3.0
# 25%       1.000000      3.0
# 50%       2.000000      3.0
# 75%       2.000000      3.0
# max       2.000000      3.0
# CLUSTER 4                 5k          10k          20k         half          25k  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean     23.634413    47.406413    96.150243   101.506405   121.532138
# std       3.048672     6.242219    13.395468    14.201512    18.130838
# min       8.020000    17.120000    38.020000    40.200000    48.880000
# 25%      21.580000    43.075000    86.950000    91.650000   109.300000
# 50%      23.300000    46.650000    94.230000    99.480000   118.430000
# 75%      25.010000    50.320000   103.065000   108.665000   130.165000
# max      37.020000    78.020000   161.600000   170.320000   243.030000
#
#                30k          35k          40k     official         pace  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    148.785668   177.684178   207.157061   219.932162     8.396381
# std      23.908118    30.453507    37.472871    39.967919     1.523876
# min      60.820000    72.830000    82.380000    87.400000     3.350000
# 25%     133.110000   157.935000   182.525000   193.770000     7.400000
# 50%     144.180000   171.180000   198.720000   211.020000     8.050000
# 75%     159.825000   191.070000   223.385000   237.610000     9.075000
# max     289.930000   334.930000   405.380000   431.000000    16.320000
#
#        rank_overall  rank_in_gender_only  rank_in_division          age  \
# count   1235.000000          1235.000000       1235.000000  1235.000000
# mean   11536.737652          7719.148988       1155.251012    48.727126
# std     8077.125214          4255.188402       1026.662154    10.454542
# min       13.000000            13.000000          1.000000    19.000000
# 25%     4982.000000          4461.000000        395.500000    41.000000
# 50%     9637.000000          7394.000000        919.000000    49.000000
# 75%    17447.000000         10887.000000       1606.000000    56.000000
# max    31885.000000         17547.000000       5851.000000    77.000000
#
#         age_ranges  cluster
# count  1235.000000   1235.0
# mean      1.589474      4.0
# std       0.649687      0.0
# min       0.000000      4.0
# 25%       1.000000      4.0
# 50%       2.000000      4.0
# 75%       2.000000      4.0
# max       2.000000      4.0
