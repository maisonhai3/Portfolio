# %%
import keras as K
from keras.applications import ResNet50

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102858752/102853048 [==============================] - 740s 7us/step

# %%
import matplotlib.pyplot as plt

img = plt.imread('Training_smaller/Apricot/0_100.jpg')
plt.imshow(img)
#plt.show()

# %%
img.shape
# Out:
# (100, 100, 3)
